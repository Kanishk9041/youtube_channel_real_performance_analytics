# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\hp\\Desktop\\unified mentors project\\final project'

# %%
df=pd.read_csv('youtube_channel_real_performance_analytics.csv')

# %%
# Display basic info and first few rows
print("Dataset Info:")
df.info()
print("\nFirst 5 Rows:")
print(df.head())
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364 entries, 0 to 363
# Data columns (total 70 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ID                                  364 non-null    int64
#  1   Video Duration                      364 non-null    float64
#  2   Video Publish Time                  364 non-null    object
#  3   Days Since Publish                  364 non-null    int64
#  4   Day                                 364 non-null    int64
#  5   Month                               364 non-null    int64
#  6   Year                                364 non-null    int64
#  7   Day of Week                         364 non-null    object
#  8   Revenue per 1000 Views (USD)        364 non-null    float64
#  9   Monetized Playbacks (Estimate)      364 non-null    float64
#  10  Playback-Based CPM (USD)            364 non-null    float64
# ...

# %%
# Check for missing values
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# ID                         0
# Video Duration             0
# Video Publish Time         0
# Days Since Publish         0
# Day                        0
#                           ..
# Watch Time (hours)         0
# Subscribers                0
# Estimated Revenue (USD)    0
# Impressions                0
# Video Thumbnail CTR (%)    0
# Length: 70, dtype: int64

# %%
# Basic statistics of numerical columns
print("\nSummary Statistics:")
print(df.describe())
# Out:
# Summary Statistics:
#                ID  Video Duration  Days Since Publish         Day       Month  \
# count  364.000000      364.000000          364.000000  364.000000  364.000000
# mean   181.500000      664.239011            8.406593   15.807692    6.642857
# std    105.221988      330.646183           15.371239    8.924004    3.421521
# min      0.000000        9.000000            0.000000    1.000000    1.000000
# 25%     90.750000      496.000000            3.000000    8.000000    4.000000
# 50%    181.500000      613.000000            5.000000   16.000000    7.000000
# 75%    272.250000      786.500000            9.000000   23.000000   10.000000
# max    363.000000     2311.000000          260.000000   31.000000   12.000000
#
#               Year  Revenue per 1000 Views (USD)  \
# count   364.000000                    364.000000
# mean   2018.736264                      0.112283
# std       2.530629                      0.179668
# ...

# %%
# Visualization: Distribution of Views
plt.figure(figsize=(10,5))
sns.histplot(df['Views'], bins=30, kde=True)
plt.title('Distribution of Video Views')
plt.xlabel('Views')
plt.ylabel('Frequency')
plt.show()

# %%
# Select only numeric columns
numeric_df = df.select_dtypes(include=['number'])

# Compute the correlation matrix
corr_matrix = numeric_df.corr()

# Create a mask to hide the upper triangle (redundant values)
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))

# Set up the matplotlib figure
plt.figure(figsize=(16, 10))

# Draw the heatmap with improved readability
sns.heatmap(corr_matrix, mask=mask, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)

# Rotate x-axis labels for clarity
plt.xticks(rotation=45, ha='right')

plt.title("Improved Correlation Heatmap")
plt.show()

# %%
import numpy as np

# %%
# Scatter plot: Likes vs Views
plt.figure(figsize=(8,5))
sns.scatterplot(x=df['Views'], y=df['Likes'], alpha=0.7)
plt.xlabel('Views')
plt.ylabel('Likes')
plt.title('Views vs Likes')
plt.show()

# %%
# Conclusion
print("\nKey Takeaways:")
print("1. Summary statistics provide insights into the distribution of key metrics.")
print("2. Visualizations highlight trends and correlations, such as the relation between views and likes.")
# Out:
# Key Takeaways:
# 1. Summary statistics provide insights into the distribution of key metrics.
# 2. Visualizations highlight trends and correlations, such as the relation between views and likes.
